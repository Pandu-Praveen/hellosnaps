# %%
import cv2 as cv
import matplotlib.pyplot as plt
import face_recognition

# %%
image = cv.imread(r"C:\Users\91934\Downloads\hellosnaps-master\server\Hello_Snaps-main\artifacts\test2.jpg")
plt.imshow(image)

# %%
img_rbg = cv.cvtColor(image,cv.COLOR_BGR2RGB)

# %%
face_recognition.face_locations(img_rbg)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 face_recognition.face_locations(img_rbg)
#
# File c:\Users\91934\Downloads\hellosnaps-master\.venv\lib\site-packages\face_recognition\api.py:121, in face_locations(img, number_of_times_to_upsample, model)
#     119     return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120 else:
# --> 121     return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#
# File c:\Users\91934\Downloads\hellosnaps-master\.venv\lib\site-packages\face_recognition\api.py:105, in _raw_face_locations(img, number_of_times_to_upsample, model)
#     103     return cnn_face_detector(img, number_of_times_to_upsample)
#     104 else:
# ...
